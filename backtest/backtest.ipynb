# %%
import pandas as pd
import numpy as np

# %%
price = pd.read_csv("../data/bitcoin_price.csv")

# %%
def backtest():
    
    return
# Out:
#    Currency      Date  Closing Price (USD)  24h Open (USD)  24h High (USD)  \
# 0       BTC  24/11/20          18469.20047     18405.55570     18752.16004
# 1       BTC  25/11/20          19045.73647     18370.21961     19392.90868
# 2       BTC  26/11/20          18746.93481     19136.08297     19391.46366
# 3       BTC  27/11/20          17187.40628     18719.20716     18908.63553
# 4       BTC  28/11/20          17023.96140     17180.71873     17482.20010
# ..      ...       ...                  ...             ...             ...
# 87      BTC   19/2/21          51728.50880     52146.00339     52532.29712
# 88      BTC   20/2/21          55719.20436     51598.14371     56283.54984
# 89      BTC   21/2/21          54801.64864     55917.03918     57487.02831
# 90      BTC   22/2/21          57128.64261     55913.35145     58332.36462
# 91      BTC   23/2/21          54181.91465     57453.35801     57535.86348
#
#     24h Low (USD)
# 0     17990.11089
# 1     18059.26543
# ...
