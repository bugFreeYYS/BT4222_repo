# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('backtest_result.csv')

# %%
for column in df.columns:
    df[column] = np.log(df[column]/df[column].shift(1))
df = df.dropna()

# %%
output = df.describe()
output
# Out:
#        logistic_c_without_sentiment  logistic_c_with_sentiment  \
# count                     26.000000                  26.000000
# mean                      -0.001245                  -0.000808
# std                        0.030851                   0.020812
# min                       -0.058367                  -0.046418
# 25%                       -0.019117                  -0.011781
# 50%                       -0.000257                   0.001841
# 75%                        0.016600                   0.007750
# max                        0.065794                   0.052089
#
#        linear_r_without_sentiment  linear_r_with_sentiment  \
# count                   26.000000                26.000000
# mean                    -0.000042                -0.001933
# std                      0.027777                 0.020862
# min                     -0.058367                -0.046418
# 25%                     -0.016682                -0.013323
# 50%                      0.003514                 0.001539
# 75%                      0.016600                 0.007694
# max                      0.064698                 0.052089
#
#        BNN_c_without_sentiment  BNN_c_with_sentiment  BNN_r_without_sentiment  \
# count                26.000000             26.000000                26.000000
# mean                  0.008148              0.001412                 0.010409
# std                   0.029619              0.016946                 0.014835
# min                  -0.070429             -0.042458                -0.020425
# 25%                  -0.006480              0.000137                 0.001685
# 50%                   0.004930              0.004646                 0.008477
# 75%                   0.028150              0.009033                 0.018900
# max                   0.064698              0.028384                 0.040268
#
#        BNN_r_with_sentiment  LSTM_c_without_sentiment  LSTM_c_with_sentiment  \
# count             26.000000                 26.000000              26.000000
# mean               0.007261                  0.002184              -0.000626
# std                0.008099                  0.030735               0.022031
# min               -0.002902                 -0.058367              -0.046418
# 25%                0.001760                 -0.016682              -0.013323
# 50%                0.005192                  0.003514               0.001539
# 75%                0.011006                  0.019152               0.008036
# max                0.032478                  0.065794               0.052089
#
#        LSTM_r_without_sentiment  LSTM_r_with_sentiment  \
# count                 26.000000              26.000000
# mean                   0.002709               0.002484
# std                    0.026837               0.009053
# min                   -0.058367              -0.024453
# 25%                   -0.012309               0.001302
# 50%                    0.004489               0.003350
# 75%                    0.019741               0.004894
# max                    0.049407               0.019343
#
#        XGBoost_c_without_sentiment  XGBoost_c_with_sentiment  \
# count                    26.000000                 26.000000
# mean                      0.002184                 -0.000626
# std                       0.030735                  0.022031
# min                      -0.058367                 -0.046418
# 25%                      -0.016682                 -0.013323
# 50%                       0.003514                  0.001539
# 75%                       0.019152                  0.008036
# max                       0.065794                  0.052089
#
#        XGBoost_r_without_sentiment  XGBoost_r_with_sentiment  \
# count                    26.000000                 26.000000
# mean                     -0.001757                  0.003594
# std                       0.029632                  0.015037
# min                      -0.070429                 -0.041660
# 25%                      -0.016881                 -0.001124
# 50%                       0.000257                  0.004023
# 75%                       0.013520                  0.008422
# max                       0.055147                  0.052089
#
#        VAR_r_without_sentiment  VAR_r_with_sentiment
# count                26.000000             26.000000
# mean                  0.006411              0.003136
# std                   0.023953              0.017483
# min                  -0.053361             -0.041660
# 25%                  -0.000288             -0.001976
# 50%                   0.006678              0.002932
# 75%                   0.019265              0.008382
# max                   0.064698              0.052089

# %%
(output.iloc[1]/output.iloc[2]).apply(lambda x: round(x, 2))
# Out:
# logistic_c_without_sentiment   -0.04
# logistic_c_with_sentiment      -0.04
# linear_r_without_sentiment     -0.00
# linear_r_with_sentiment        -0.09
# BNN_c_without_sentiment         0.28
# BNN_c_with_sentiment            0.08
# BNN_r_without_sentiment         0.70
# BNN_r_with_sentiment            0.90
# LSTM_c_without_sentiment        0.07
# LSTM_c_with_sentiment          -0.03
# LSTM_r_without_sentiment        0.10
# LSTM_r_with_sentiment           0.27
# XGBoost_c_without_sentiment     0.07
# XGBoost_c_with_sentiment       -0.03
# XGBoost_r_without_sentiment    -0.06
# XGBoost_r_with_sentiment        0.24
# VAR_r_without_sentiment         0.27
# VAR_r_with_sentiment            0.18
# dtype: float64

# %%
output.iloc[2]
# Out:
# logistic_c_without_sentiment    0.030851
# logistic_c_with_sentiment       0.020812
# linear_r_without_sentiment      0.027777
# linear_r_with_sentiment         0.020862
# BNN_c_without_sentiment         0.029619
# BNN_c_with_sentiment            0.016946
# BNN_r_without_sentiment         0.014835
# BNN_r_with_sentiment            0.008099
# LSTM_c_without_sentiment        0.030735
# LSTM_c_with_sentiment           0.022031
# LSTM_r_without_sentiment        0.026837
# LSTM_r_with_sentiment           0.009053
# XGBoost_c_without_sentiment     0.030735
# XGBoost_c_with_sentiment        0.022031
# XGBoost_r_without_sentiment     0.029632
# XGBoost_r_with_sentiment        0.015037
# VAR_r_without_sentiment         0.023953
# VAR_r_with_sentiment            0.017483
# Name: std, dtype: float64
